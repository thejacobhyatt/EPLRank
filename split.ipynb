# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv('agg_2024.csv')
# df = df[df['Wk'] == 1.0]
df
# Out:
#      HMin  HGls  HAst  HPK  HPKatt  HSh  HSoT  HCrdY  HCrdR  HTouches  ...  \
# 0     989     0     0    0       0    6     1      0      1       496  ...
# 1     990     2     2    0       0   15     7      2      0       902  ...
# 2     990     0     0    0       0   19     9      0      0       531  ...
# 3     990     0     0    0       0    8     1      3      0       441  ...
# 4     990     4     2    1       1   26    11      2      0       769  ...
# ..    ...   ...   ...  ...     ...  ...   ...    ...    ...       ...  ...
# 375   990     2     2    0       0   10     5      4      0       606  ...
# 376   990     2     1    0       0   16     6      2      0       695  ...
# 377   990     5     4    0       0   15     9      1      0       663  ...
# 378   990     2     1    0       0   36    13      1      0       779  ...
# 379   990     1     1    0       0   20     3      1      0       787  ...
#
# ...

# %%
columns_starting_with_A = ['match_id'] + [col for col in df.columns if col.startswith('A')]
df[columns_starting_with_A]
# Out:
#      match_id  AMin  AGls  AAst  APK  APKatt  ASh  ASoT  ACrdY  ACrdR  ...  \
# 0           0   990     3     2    0       0   17     8      0      0  ...
# 1           1   990     1     1    0       0    6     2      2      0  ...
# 2           2   990     1     0    0       0    9     2      2      0  ...
# 3           3   990     1     1    0       0   24     8      0      0  ...
# 4           4   990     1     0    1       1    8     2      2      0  ...
# ..        ...   ...   ...   ...  ...     ...  ...   ...    ...    ...  ...
# 375       375   990     4     3    0       0   12     7      4      0  ...
# 376       376   990     0     0    0       0   22     5      3      0  ...
# 377       377   990     0     0    0       0    8     2      4      0  ...
# 378       378   927     0     0    0       0    4     2      1      1  ...
# 379       379   990     2     2    0       0   12     6      0      0  ...
#
# ...

# %%
columns_starting_with_A = ['match_id'] + [col for col in df.columns if col.startswith('H')]
df[columns_starting_with_A]
# Out:
#      match_id  HMin  HGls  HAst  HPK  HPKatt  HSh  HSoT  HCrdY  HCrdR  ...  \
# 0           0   989     0     0    0       0    6     1      0      1  ...
# 1           1   990     2     2    0       0   15     7      2      0  ...
# 2           2   990     0     0    0       0   19     9      0      0  ...
# 3           3   990     0     0    0       0    8     1      3      0  ...
# 4           4   990     4     2    1       1   26    11      2      0  ...
# ..        ...   ...   ...   ...  ...     ...  ...   ...    ...    ...  ...
# 375       375   990     2     2    0       0   10     5      4      0  ...
# 376       376   990     2     1    0       0   16     6      2      0  ...
# 377       377   990     5     4    0       0   15     9      1      0  ...
# 378       378   990     2     1    0       0   36    13      1      0  ...
# 379       379   990     1     1    0       0   20     3      1      0  ...
#
# ...
