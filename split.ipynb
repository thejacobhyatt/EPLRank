# %%
import pandas as pd

# %% [markdown]
# Split the data from games to just team performance that leads to win or loss

# %%
df = pd.read_csv('final_2023.csv')
df
# Out:
#        Wk  Day        Date   Time            Home  HxG Score  AxG  \
# 0     1.0  Fri  2022-08-05  20:00  Crystal Palace  1.2   0–2  1.0
# 1     1.0  Sat  2022-08-06  12:30          Fulham  1.2   2–2  1.2
# 2     1.0  Sat  2022-08-06  15:00       Tottenham  1.5   4–1  0.5
# 3     1.0  Sat  2022-08-06  15:00   Newcastle Utd  1.7   2–0  0.3
# 4     1.0  Sat  2022-08-06  15:00    Leeds United  0.8   2–1  1.3
# ..    ...  ...         ...    ...             ...  ...   ...  ...
# 375  38.0  Sun  2023-05-28  16:30         Everton  1.0   1–0  0.5
# 376  38.0  Sun  2023-05-28  16:30  Leicester City  1.4   2–1  1.4
# 377  38.0  Sun  2023-05-28  16:30     Aston Villa  2.8   2–1  1.4
# 378  38.0  Sun  2023-05-28  16:30    Leeds United  1.5   1–4  2.2
# 379  38.0  Sun  2023-05-28  16:30       Brentford  1.3   1–0  1.6
#
#                 Away                                     MatchReportURL  ...  \
# 0            Arsenal  https://fbref.com/en/matches/e62f6e78/Crystal-...  ...
# ...

# %%
df['Match_ID']
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 375    375
# 376    376
# 377    377
# 378    378
# 379    379
# Name: Match_ID, Length: 380, dtype: int64

# %%
away_columns = ['Match_ID'] + [col for col in df.columns if col.startswith('A')]

print(away_columns)
len(away_columns)
# Out:
# ['Match_ID', 'AxG', 'Away', 'Away_Score', 'A__Min', 'A_Performance_Gls', 'A_Performance_Ast', 'A_Performance_PK', 'A_Performance_PKatt', 'A_Performance_Sh', 'A_Performance_SoT', 'A_Performance_CrdY', 'A_Performance_CrdR', 'A_Performance_Touches', 'A_Performance_Tkl', 'A_Performance_Int', 'A_Performance_Blocks', 'A_Expected_xG', 'A_Expected_npxG', 'A_Expected_xAG', 'A_SCA_SCA', 'A_SCA_GCA', 'A_Passes_Cmp', 'A_Passes_Att', 'A_Passes_Cmp%', 'A_Passes_PrgP', 'A_Carries_Carries', 'A_Carries_PrgC', 'A_Take-Ons_Att', 'A_Take-Ons_Succ', 'A__Min.1', 'A_Total_Cmp', 'A_Total_Att', 'A_Total_Cmp%', 'A_Total_TotDist', 'A_Total_PrgDist', 'A_Short_Cmp', 'A_Short_Att', 'A_Short_Cmp%', 'A_Medium_Cmp', 'A_Medium_Att', 'A_Medium_Cmp%', 'A_Long_Cmp', 'A_Long_Att', 'A_Long_Cmp%', 'A__Ast', 'A__xAG', 'A__xA', 'A__KP', 'A__1/3', 'A__PPA', 'A__CrsPA', 'A__PrgP', 'A__Min.2', 'A__Att', 'A_Pass Types_Live', 'A_Pass Types_Dead', 'A_Pass Types_FK', 'A_Pass Types_TB', 'A_Pass Types_Sw', 'A_Pass Types_Crs', 'A_Pass
# ...

# %%
home_columns = ['Match_ID'] + [col for col in df.columns if col.startswith('H')]
print(home_columns)
len(home_columns)
# Out:
# ['Match_ID', 'Home', 'HxG', 'Home_Score', 'H__Min', 'H_Performance_Gls', 'H_Performance_Ast', 'H_Performance_PK', 'H_Performance_PKatt', 'H_Performance_Sh', 'H_Performance_SoT', 'H_Performance_CrdY', 'H_Performance_CrdR', 'H_Performance_Touches', 'H_Performance_Tkl', 'H_Performance_Int', 'H_Performance_Blocks', 'H_Expected_xG', 'H_Expected_npxG', 'H_Expected_xAG', 'H_SCA_SCA', 'H_SCA_GCA', 'H_Passes_Cmp', 'H_Passes_Att', 'H_Passes_Cmp%', 'H_Passes_PrgP', 'H_Carries_Carries', 'H_Carries_PrgC', 'H_Take-Ons_Att', 'H_Take-Ons_Succ', 'H__Min.1', 'H_Total_Cmp', 'H_Total_Att', 'H_Total_Cmp%', 'H_Total_TotDist', 'H_Total_PrgDist', 'H_Short_Cmp', 'H_Short_Att', 'H_Short_Cmp%', 'H_Medium_Cmp', 'H_Medium_Att', 'H_Medium_Cmp%', 'H_Long_Cmp', 'H_Long_Att', 'H_Long_Cmp%', 'H__Ast', 'H__xAG', 'H__xA', 'H__KP', 'H__1/3', 'H__PPA', 'H__CrsPA', 'H__PrgP', 'H__Min.2', 'H__Att', 'H_Pass Types_Live', 'H_Pass Types_Dead', 'H_Pass Types_FK', 'H_Pass Types_TB', 'H_Pass Types_Sw', 'H_Pass Types_Crs', 'H_Pass
# ...
